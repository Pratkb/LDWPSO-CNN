# %%
import time
import numpy as np
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import optimizers
# from hyperactive import Hyperactive
from Hyperactive.hyperactive import RandomSearchOptimizer, ParticleSwarmOptimizer

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train = X_train.astype('float32')/255.0
X_test = X_test.astype('float32')/255.0

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)


sgd = optimizers.SGD(lr=0.01)
adam = optimizers.Adam(lr=0.01)

# this defines the structure of the model and print("time: {}".format(t2-t1))the search space in each layer
search_config = {
    "keras.compile.0": {"loss": ["categorical_crossentropy"], "optimizer": [adam, sgd]},
    "keras.fit.0": {"epochs": [10], "batch_size": range(10, 101), "verbose": [2]},
    "keras.layers.Conv2D.1": {
        "filters": range(4, 101),
        "kernel_size": [3, 5, 7],
        "activation": ["sigmoid", "relu", "tanh"],
        "input_shape": [(32, 32, 3)],
    },
    "keras.layers.MaxPooling2D.2": {"pool_size": [(2, 2)]},
    "keras.layers.Conv2D.3": {
        "filters": range(4, 101),
        "kernel_size": [3, 5, 7],
        "activation": ["sigmoid", "relu", "tanh"],
    },
    "keras.layers.MaxPooling2D.4": {"pool_size": [(2, 2)]},
    "keras.layers.Flatten.5": {},
    "keras.layers.Dense.6": {"units": range(4, 201), "activation": ["sigmoid", "relu", "tanh"]},
    "keras.layers.Dense.7": {"units": range(4, 201), "activation": ["sigmoid", "relu", "tanh"]},
    #"keras.layers.Dropout.7": {"rate": list(np.arange(0.2, 0.8, 0.2))},
    "keras.layers.Dense.8": {"units": [10], "activation": ["softmax"]},
}

Optimizer = ParticleSwarmOptimizer(search_config, n_iter=10, n_part=10, metric='accuracy', cv=0.8, w=0.7, c_k=2.0, c_s=2.0)

t1 = time.time()
Optimizer.fit(X_train, y_train)
t2 = time.time()

print("time: {}".format(t2-t1))

# predict from test data
Optimizer.predict(X_test)
score = Optimizer.score(X_test, y_test)

print("test score: {}".format(score))
# Out:
# C:\Users\balachp\Anaconda3\lib\site-packages\keras\optimizer_v2\gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# C:\Users\balachp\Anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/10
# 678/678 - 45s - loss: 2.2949 - accuracy: 0.1180 - 45s/epoch - 67ms/step
# Epoch 2/10
# 678/678 - 46s - loss: 2.2270 - accuracy: 0.1805 - 46s/epoch - 68ms/step
# Epoch 3/10
# 678/678 - 58s - loss: 2.1136 - accuracy: 0.2360 - 58s/epoch - 86ms/step
# Epoch 4/10
# 678/678 - 73s - loss: 1.9903 - accuracy: 0.2824 - 73s/epoch - 108ms/step
# Epoch 5/10
# 678/678 - 72s - loss: 1.8980 - accuracy: 0.3169 - 72s/epoch - 105ms/step
# Epoch 6/10
# 678/678 - 80s - loss: 1.8264 - accuracy: 0.3366 - 80s/epoch - 118ms/step
# Epoch 7/10
# 678/678 - 66s - loss: 1.7611 - accuracy: 0.3582 - 66s/epoch - 97ms/step
# Epoch 8/10
# 678/678 - 48s - loss: 1.7021 - accuracy: 0.3791 - 48s/epoch - 71ms/step
# Epoch 9/10
# 678/678 - 49s - loss: 1.6531 - accuracy: 0.3958 - 49s/epoch - 72ms/step
# Epoch 10/10
# 678/678 - 47s - loss: 1.6075 - accuracy: 0.4089 - 47s/epoch - 69ms/step
# iter: 1
# weight :0.9
# Epoch 1/10
# 513/513 - 36s - loss: 2.3116 - accuracy: 0.1260 - 36s/epoch - 71ms/step
# Epoch 2/10
# 513/513 - 34s - loss: 2.2923 - accuracy: 0.1573 - 34s/epoch - 66ms/step
# Epoch 3/10
# 513/513 - 37s - loss: 2.2673 - accuracy: 0.1927 - 37s/epoch - 73ms/step
# Epoch 4/10
# 513/513 - 37s - loss: 2.2294 - accuracy: 0.1972 - 37s/epoch - 73ms/step
# Epoch 5/10
# 513/513 - 34s - loss: 2.1848 - accuracy: 0.1997 - 34s/epoch - 67ms/step
# Epoch 6/10
# 513/513 - 34s - loss: 2.1389 - accuracy: 0.2001 - 34s/epoch - 67ms/step
# Epoch 7/10
# 513/513 - 34s - loss: 2.0984 - accuracy: 0.2079 - 34s/epoch - 67ms/step
# Epoch 8/10
# 513/513 - 34s - loss: 2.0645 - accuracy: 0.2209 - 34s/epoch - 66ms/step
# Epoch 9/10
# 513/513 - 37s - loss: 2.0287 - accuracy: 0.2254 - 37s/epoch - 72ms/step
# Epoch 10/10
# 513/513 - 37s - loss: 1.9888 - accuracy: 0.2377 - 37s/epoch - 73ms/step
# Epoch 1/10
# 1053/1053 - 42s - loss: 2.3272 - accuracy: 0.0980 - 42s/epoch - 40ms/step
# Epoch 2/10
# 1053/1053 - 42s - loss: 2.3189 - accuracy: 0.0994 - 42s/epoch - 40ms/step
# Epoch 3/10
# 1053/1053 - 41s - loss: 2.3189 - accuracy: 0.1037 - 41s/epoch - 39ms/step
# Epoch 4/10
# 1053/1053 - 41s - loss: 2.3188 - accuracy: 0.0989 - 41s/epoch - 39ms/step
# Epoch 5/10
# 1053/1053 - 42s - loss: 2.3214 - accuracy: 0.0991 - 42s/epoch - 39ms/step
# Epoch 6/10
# 1053/1053 - 42s - loss: 2.3170 - accuracy: 0.0978 - 42s/epoch - 39ms/step
# Epoch 7/10
# 1053/1053 - 41s - loss: 2.3189 - accuracy: 0.1002 - 41s/epoch - 39ms/step
# Epoch 8/10
# 1053/1053 - 39s - loss: 2.3196 - accuracy: 0.0989 - 39s/epoch - 37ms/step
# Epoch 9/10
# 1053/1053 - 38s - loss: 2.3171 - accuracy: 0.0987 - 38s/epoch - 36ms/step
# Epoch 10/10
# 1053/1053 - 38s - loss: 2.3177 - accuracy: 0.0987 - 38s/epoch - 36ms/step
# Epoch 1/10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3104/1709216672.py in <module>
#      38
#      39 t1 = time.time()
# ---> 40 Optimizer.fit(X_train, y_train)
#      41 t2 = time.time()
#      42
#
# ~\Desktop\per_work\Kavya\Hyperactive\hyperactive\base_optimizer.py in fit(self, X, y)
#     199
#     200         if self._config_.n_jobs == 1:
# --> 201             self._run_one_job(X, y)
#     202
#     203         else:
#
# ~\Desktop\per_work\Kavya\Hyperactive\hyperactive\base_optimizer.py in _run_one_job(self, X, y)
#     136
#     137     def _run_one_job(self, X, y):
# --> 138         _cand_ = self.search(0, X, y)
#     139         if self._config_.meta_learn:
#     140             self._meta_.collect(X, y, _cand_list=[_cand_])
#
# ~\Desktop\per_work\Kavya\Hyperactive\hyperactive\base_optimizer.py in search(self, nth_process, X, y)
#     103             print("iter:", i+1)
#     104
# --> 105             _cand_ = self._iterate(i, _cand_, _p_, X, y)
#     106             self._config_.update_p_bar(1)
#     107
#
# ~\Desktop\per_work\Kavya\Hyperactive\hyperactive\optimizers\population\particle_swarm_optimization.py in _iterate(self, i, _cand_, _p_list_, X, y)
#      55     def _iterate(self, i, _cand_, _p_list_, X, y):
#      56         self._move_particles(_cand_, _p_list_, i)
# ---> 57         self._eval_particles(_cand_, _p_list_, X, y)
#      58
#      59         return _cand_
#
# ~\Desktop\per_work\Kavya\Hyperactive\hyperactive\optimizers\population\particle_swarm_optimization.py in _eval_particles(self, _cand_, _p_list_, X, y)
#      48     def _eval_particles(self, _cand_, _p_list_, X, y):
#      49         for _p_ in _p_list_:
# ---> 50             _p_.score_new = _cand_.eval_pos(_p_.pos_new, X, y)
#      51
#      52             if _p_.score_new > _cand_.score_best:
#
# ~\Desktop\per_work\Kavya\Hyperactive\hyperactive\candidate\candidate.py in eval_pos(self, pos, X, y, force_eval)
#      35         else:
#      36             para = self._space_.pos2para(pos)
# ---> 37             score, self.model = self._model_.train_model(para, X, y)
#      38
#      39             self._space_.memory[pos_str] = score
#
# ~\Desktop\per_work\Kavya\Hyperactive\hyperactive\model\model_keras.py in train_model(self, keras_para_dict, X, y)
#     147             fit_para_dict["x"] = X_train
#     148             fit_para_dict["y"] = y_train
# --> 149             model.fit(**fit_para_dict)
#     150             # y_pred = model.predict(X_test)
#     151             # score = self.metric_class(y_test, y_pred)
#
# ~\Anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2954       (graph_function,
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956     return graph_function._call_flat(
#    2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1851         and executing_eagerly):
#    1852       # No tape is watching; skip to running the function.
# -> 1853       return self._build_call_outputs(self._inference_function.call(
#    1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     497       with _InterpolateFunctionError(self):
#     498         if cancellation_manager is None:
# --> 499           outputs = execute.execute(
#     500               str(self.signature.name),
#     501               num_outputs=self._num_outputs,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
